# %%
import numpy as np 
a1 = np.arange(1,6)
a2 = np.arange(6,11)
a1
# Out:
# array([1, 2, 3, 4, 5])

# %%
a2
# Out:
# array([ 6,  7,  8,  9, 10])

# %%
# if you want to add array elament withr espect to the index like 0+0 1+1 2+2 3+3 4+4
arr=a1+a2
arr
# Out:
# array([ 7,  9, 11, 13, 15])

# %%
# Out:
# array([-5, -5, -5, -5, -5])

# %%
# Out:
# array([0.16666667, 0.28571429, 0.375     , 0.44444444, 0.5       ])

# %%
# Out:
# array([ 6, 14, 24, 36, 50])

# %%
# Out:
# array([1, 2, 3, 4, 5])

# %%
# Out:
# array([      1,     128,    6561,  262144, 9765625])
